# %%
first = "welcome dain!"

# %%
first
# Out:
# 'welcome dain!'

# %%
first = 'good day!'

# %%
first
# Out:
# 'good day!'

# %%
second = "Life is simple.'really?'"

# %%
second
# Out:
# "Life is simple.'really?'"

# %%
first = second

# %%
third = "life is " + 'good!'

# %%
third = "lige is " + first

# %%
third = first + " " + second

# %%
third
# Out:
# "welcome dain! Life is simple.'really?'"

# %% [markdown]
# ## 문제 풀이
# - 두 문자열 변수를 선언해서 각각 변수에 값을 넣고, + 기호를 이용해 이어 붙이는 코드를 작성.
# - 변수 이름 : first, second, result
#
# 결과) 'Good Morning'

# %%
first = 'Good '

# %%
second = 'Morning'

# %%
result = first + second

# %%
result
# Out:
# 'Good Morning'
