# %%
first = { "second" : "good" }

# %%
first
# Out:
# {'second': 'good'}

# %%
first ["second"]
# Out:
# 'good'

# %%
second = {
    "first" : "good",
    "second" : "bad"
}

# %%
second ["second"]
# Out:
# 'bad'

# %%
third = "not bad"

# %%
second = {
    "first" : "good",
    "second" : "bad",
    "not_key" : third
}

# %%
second
# Out:
# {'first': 'good', 'second': 'bad', 'not_key': 'not bad'}

# %%
second ["not_key"]
# Out:
# 'not bad'

# %% [markdown]
# ## 문제 풀이

# %% [markdown]
# 🟩 문제 1. 딕셔너리 만들기
# 이름과 직업을 키와 값으로 가지는 딕셔너리를 만들어 보세요.
# 변수 이름: `person`
#
# ```python
# # 키: "name", 값: "Alice"
# # 키: "job", 값: "Engineer"
# # person 딕셔너리를 만들어 보세요
# ```

# %%
person = {"name" : "Alice", "job" : "Engineer"}

# %%
person
# Out:
# {'name': 'Alice', 'job': 'Engineer'}

# %% [markdown]
# 🟩 문제 2. 딕셔너리 값 접근하기
# 다음과 같은 딕셔너리가 있습니다.
# `"city"`에 해당하는 값을 출력하는 코드를 작성해 보세요.
#
# ```python
# info = {
#     "name": "Bob",
#     "age": "25",
#     "city": "Seoul"
# }
# # "city" 값을 출력
# ```

# %%
info = {
    "name": "Bob",
    "age": "25",
    "city": "Seoul"
}

# %%
info ["city"]
# Out:
# 'Seoul'

# %% [markdown]
# 🟩 문제 3. 딕셔너리 값 바꾸기
# 다음과 같은 딕셔너리가 있습니다.
# `"age"` 값을 `"30"`으로 바꾸고, `"name"` 값을 `"Charlie"`로 바꾸는 코드를 작성해 보세요.
#
# ```python
# info = {
#     "name": "Bob",
#     "age": "25",
#     "city": "Seoul"
# }
# # "age" 값을 "30"으로 변경
# # "name" 값을 "Charlie"로 변경

# %%
info = {
    "name": "Bob",
    "age": "25",
    "city": "Seoul"
}

# %%
info
# Out:
# {'name': 'Bob', 'age': '25', 'city': 'Seoul'}

# %%
age1 = "30"
name1 = "Charlin"

# %%
info["age"] = age1
info["name"] = name1

# %%
info
# Out:
# {'name': 'Charlin', 'age': '30', 'city': 'Seoul'}

# %%
third = "not bad"
second = {
    "first" : "good",
    "second" : "bad",
    "not_key" : third
}
