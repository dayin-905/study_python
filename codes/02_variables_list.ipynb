# %% [markdown]
# ## 단일 리스트
# -

# %%
first = ['1', '2', '3', '4']

# %%
first
# Out:
# ['1', '2', '3', '4']

# %%
type(first)
# Out:
# list

# %%
second = "['1', '2', '3', '4']"

# %%
second
# Out:
# "['1', '2', '3', '4']"

# %%
type(second)
# Out:
# str

# %%
first [2]
# Out:
# '3'

# %%
first [0]
# Out:
# '1'

# %%
second = ['morning',
        'afternoon',
        'night']

# %%
second
# Out:
# ['morning', 'afternoon', 'night']

# %%
second [1]
# Out:
# 'afternoon'

# %%
night = 'night'

# %%
third = ['morning',
        'afternoon',
        'night']

# %%
night
# Out:
# '8'

# %%
third
# Out:
# ['morning', 'afternoon', 'night']

# %% [markdown]
# ## 문제 풀이

# %% [markdown]
# ### 🟩 문제 1. 리스트 만들기
# 세 개의 문자열을 각각 변수에 저장하고, 이들을 하나의 리스트에 넣어 보세요.
# 변수 이름은 `fruit1`, `fruit2`, `fruit3`이고, 리스트 이름은 `fruits`입니다.
# ```python
# fruit1 = "apple"
# fruit2 = "banana"
# fruit3 = "cherry"
# # 여기에 fruits 리스트를 만들어 보세요
# ```

# %%
fruit1 = 'apple'

# %%
fruit2 = 'banana'

# %%
fruit3 = 'cherry'

# %%
fruits = ['fruit1', 'fruit2', 'fruit3']

# %%
fruits
# Out:
# ['fruit1', 'fruit2', 'fruit3']

# %% [markdown]
# ### 🟩 문제 2. 리스트 안의 값 접근하기
# 문자열 세 개가 들어 있는 리스트 `colors`가 있습니다.
# 리스트의 두 번째 값(인덱스 1)을 `print`로 출력해 보세요.
#
# ```python
# colors = ["red", "green", "blue"]
# # 두 번째 값을 출력
# ```

# %%
colors = ["red", "green", "blue"]

# %%
colors
# Out:
# ['red', 'green', 'blue']

# %%
colors [1]
# Out:
# 'green'

# %% [markdown]
# ### 🟩 문제 3. 리스트 값 바꾸기
# 문자열이 들어 있는 리스트 `pets`가 있습니다.
# 리스트의 요청 사항을 출력
#
# ```python
# pets = ["dog", "parrot", "fish", "red", "green", "blue"]
# # "dog" 값을 출력
# # ‘green’ 값을 출력
# ```

# %%
pets = ["dog", "parrot", "fish", "red", "green", "blue"]

# %%
pets
# Out:
# ['dog', 'parrot', 'fish', 'red', 'green', 'blue']

# %%
pets [0]
# Out:
# 'dog'

# %%
pets [4]
# Out:
# 'green'
